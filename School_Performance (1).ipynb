# %% [markdown]
# The purpose of the study is to determine whether gender,race/ethnicity,parental_level_of_education,
# lunch and test_preparation_course have any effect on math,reading and writing scores.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
test = pd.read_csv(r"C:\--------\StudentsPerformance.csv")

# %%
test.columns=test.columns.str.replace(' ','_')
test.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Checking the data types of the data set, null values-- test.dtypes can be used to observe only the data types
test.info(verbose=True) #verbose=True displays if there is null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental_level_of_education    1000 non-null object
# lunch                          1000 non-null object
# test_preparation_course        1000 non-null object
# math_score                     1000 non-null int64
# reading_score                  1000 non-null int64
# writing_score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
'''EXAMINING THE DISTRIBUTIONS OF categorical data'''
test_object = test[test.dtypes[test.dtypes==object].index]
test_numeric = test[test.dtypes[test.dtypes=='int64'].index]

# %%
#Ploting the frequency distribution of categorical data
fig = plt.figure(figsize=(20, 6))
fig.subplots_adjust(hspace=0.6, wspace=0.2)
for i in range(1, 6):
    #print(pd.value_counts(test_object.iloc[:,i-1],normalize=True),'\n')
    ax = fig.add_subplot(2, 3, i)
    ax.hist(test_object.iloc[:,i-1])
    plt.title(test.columns[i-1]+' distribution')
    plt.xlabel(test.columns[i-1])
    plt.ylabel('count')
    plt.xticks(rotation=45, ha="right")
plt.show()        
test.describe(include=np.object)
# Out:
#         gender race/ethnicity parental_level_of_education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test_preparation_course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
fig = plt.figure(figsize=(20, 6))
fig.subplots_adjust(hspace=0.6, wspace=0.2)
for i in range(1, 4):
    #print(pd.value_counts(test_object.iloc[:,i-1],normalize=True),'\n')
    ax = fig.add_subplot(1, 3, i)
    ax.hist(test_numeric.iloc[:,i-1])
    plt.title(test_numeric.columns[i-1]+' distribution')
    plt.xlabel(test_numeric.columns[i-1])
    plt.ylabel('count')
    plt.xticks(rotation=45, ha="right")
plt.show()        
test.describe(include=np.number)
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#distribution plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
for i in range(3):
    x= test_numeric.iloc[:,i]
    #subplot(1,3,i+1)
    ax = sns.distplot(x)
plt.show()

# %%
x= test_numeric.iloc[:,0:1]

# %%
test_numeric.iloc[:,1]
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading_score, Length: 1000, dtype: int64

# %% [markdown]
# <ul> <b>EXAMINING THE DISTRIBUTIONS </b>
#     <li>Examine distributions of data.</li>
#     <li>Explain and interpret measures of location, dispersion,and shape.</li>
#     <li>Use the MEANS and UNIVARIATE procedures to produce descriptive statistics.</li>
#     <li>Use the UNIVARIATE procedure to generate histograms and normal probability plots. Assumption for This dataset</li>
#     <li>The sample drawn is representative of the population.</li>
# </ul>

# %%
test['Average_score'] = test.mean(axis=1)
test.head(5)
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Average_score
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333

# %%
#EXAMINING THE DISTRIBUTION OF NUMERIC DATA
test.describe(include=np.number)
# Out:
#        math_score  reading_score  writing_score  Average_score
# count  1000.00000    1000.000000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000      67.770667
# std      15.16308      14.600192      15.195657      14.257326
# min       0.00000      17.000000      10.000000       9.000000
# 25%      57.00000      59.000000      57.750000      58.333333
# 50%      66.00000      70.000000      69.000000      68.333333
# 75%      77.00000      79.000000      79.000000      77.666667
# max     100.00000     100.000000     100.000000     100.000000

# %%
fig = plt.figure(figsize=(20, 6))
fig.subplots_adjust(hspace=1.8, wspace=0.2)
for i in range(1, len(test.columns)+1):
    #print(pd.value_counts(test_object.iloc[:,i-1],normalize=True),'\n')
    ax = fig.add_subplot(3, 3, i)
    ax.hist(test.iloc[:,i-1])
    #sns.distplot(test[col], hist=True)
    plt.title(test.columns[i-1]+' distribution')
    plt.xlabel(test.columns[i-1])
    plt.ylabel('count')
    plt.xticks(rotation=45, ha="center")
plt.show()

# %%
for col in test_object.columns:
    fig = plt.figure(figsize=(20, 6))
    print( test.groupby(col).mean() ,'\n-------------------\n')
    sns.boxplot(x=col ,y='Average_score', data=test)
    plt.show()
# Out:
#         math_score  reading_score  writing_score  Average_score
# gender
# female   63.633205      72.608108      72.467181      69.569498
# male     68.728216      65.473029      63.311203      65.837483
# -------------------
#                 math_score  reading_score  writing_score  Average_score
# race/ethnicity
# group A          61.629213      64.674157      62.674157      62.992509
# group B          63.452632      67.352632      65.600000      65.468421
# group C          64.463950      69.103448      67.827586      67.131661
# group D          67.362595      70.030534      70.145038      69.179389
# group E          73.821429      73.028571      71.407143      72.752381
# -------------------
#                              math_score  reading_score  writing_score  \
# parental_level_of_education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# ...

# %%
Q1 = test['Average_score'].quantile(0.25)
Q3 = test['Average_score'].quantile(0.75)
IQR = Q3 - Q1
print('first quartile-',Q1,'\nthird quartile-',Q3,'\nInter Quartile Range',IQR)

print('lower level outlier border :', (Q1 - 1.5 * IQR))
print('upper level outlier border :', (Q3 + 1.5 * IQR))

test = test[~((test['Average_score'] < (Q1 - 1.5 * IQR)) | (test['Average_score'] > (Q3 + 1.5 * IQR)))]
# Out:
# first quartile- 58.333333333333336
# third quartile- 77.66666666666667
# Inter Quartile Range 19.333333333333336
# lower level outlier border : 29.333333333333332
# upper level outlier border : 106.66666666666667

# %%
test_clean = test.drop(test_outlier.index, axis=0)

# %%
#Q1. is there any significant difference between Male and Female students on their Average Score?
sns.boxplot(x='gender', y='math_score',data=test_clean)
#test[['gender','Average score']].boxplot(by='gender')
#test_clean['math_score'].sort_values()
#test['math_score'].sort_values()

# %%
from statsmodels.formula.api import ols
from statsmodels.graphics.api import interaction_plot, abline_plot
from statsmodels.stats.anova import anova_lm

lm = ols("Average_score ~ lunch ", data=test_clean).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Average_score   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     84.55
# Date:                Tue, 17 Jan 2023   Prob (F-statistic):           2.15e-19
# Time:                        14:11:23   Log-Likelihood:                -3979.5
# No. Observations:                 994   AIC:                             7963.
# Df Residuals:                     992   BIC:                             7973.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            62.8029      0.709     88.529      0.000      61.411      64.195
# ...

# %%
from scipy import stats
F,P = stats.f_oneway(test[test.gender=='female'].Average_score,test[test.gender=='male'].Average_score)
print(F,P)
# Out:
# 18.826753659953944 1.5779479793275713e-05

# %%
#Hypothesis Testing:
'''Ho: Average score of female students = Average score of male students 
Ha: There is a significant difference on average score between gender 
    
    at 5% significant level Since p-value(=0.000) < 0.05
we reject Ho and conclude that there is a significant difference on score between the two genders
'''
# Out:
# 'Ho: Average score of female students = Average score of male students \nHa: There is a significant difference on average score between gender \n    \n    at 5% significant level Since p-value(=0.000) < 0.05\nwe reject Ho and conclude that there is a significant difference on score between the two genders\n'

# %%
from scipy import stats
F,P = stats.f_oneway(test_clean.math_score,test_clean.writing_score,test_clean.reading_score)
print(F,P)

lm2 = ols("math_score ~ gender ", data=test_clean).fit()
print(lm2.summary())

test_clean.groupby('gender').mean()
# Out:
# 11.30908303912418 1.2796142410301786e-05
#                             OLS Regression Results
# ...
# Dep. Variable:             math_score   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     29.67
# Date:                Tue, 17 Jan 2023   Prob (F-statistic):           6.46e-08
# Time:                        14:11:25   Log-Likelihood:                -4069.1
# No. Observations:                 994   AIC:                             8142.
# Df Residuals:                     992   BIC:                             8152.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         63.9534      0.640     99.931      0.000      62.698      65.209
# ...

# %%
F,P = stats.f_oneway(test.math_score[test.gender=='female'],test.math_score[test.gender=='male'])
print(F,P)

'''lm2 = ols("math_score ~ gender ", data=test_clean).fit()
print(lm2.summary())'''

test_clean.groupby('gender').math_score.mean()
# Out:
# 29.668640932269764 6.464437379208541e-08
# gender
# female    63.953398
# male      68.974948
# Name: math_score, dtype: float64

# %%
test_clean[test_clean.gender=='female'].Average_score.sort_values()
# Out:
# 601     29.333333
# 338     29.666667
# 787     29.666667
# 363     31.000000
# 145     31.333333
#           ...
# 712     99.000000
# 179     99.000000
# 114     99.666667
# 458    100.000000
# 962    100.000000
# Name: Average_score, Length: 515, dtype: float64

# %%
sns.boxplot(data=test['math_score'])

# %%
#sns.pairplot(data=test)
sns.distplot(test['Average_score'], hist=True);

# %%
from statsmodels.graphics.gofplots import qqplot
qqplot(test['Average_score'], line='s')

# %%
test_n = test[test.dtypes[test.dtypes == 'int64'].index]
test_n.boxplot()

# %%
for col in ('gender','race/ethnicity','parental_level_of_education','lunch','test_preparation_course'):
    print(test.groupby(col).mean() ,'\n\n')
# Out:
#         math_score  reading_score  writing_score  Average_score
# gender
# female   63.953398      72.889320      72.770874      69.871197
# male     68.974948      65.730689      63.590814      66.098817
#
#
#                 math_score  reading_score  writing_score  Average_score
# race/ethnicity
# group A          62.011364      65.147727      63.170455      63.443182
# group B          64.171123      68.005348      66.299465      66.158645
# group C          64.666667      69.267296      68.009434      67.314465
# group D          67.362595      70.030534      70.145038      69.179389
# group E          74.136691      73.366906      71.762590      73.088729
#
#
#                              math_score  reading_score  writing_score  \
# parental_level_of_education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.582474      65.123711      62.896907
# ...

# %%
test.describe() # include = 'all'
# Out:
#        math_score  reading_score  writing_score  Average_score
# count  994.000000     994.000000     994.000000     994.000000
# mean    66.373239      69.439638      68.347082      68.053320
# std     14.731519      14.216740      14.757020      13.818779
# min     19.000000      28.000000      27.000000      29.333333
# 25%     57.000000      60.000000      58.000000      58.333333
# 50%     66.000000      70.000000      69.000000      68.666667
# 75%     77.000000      79.750000      79.000000      77.916667
# max    100.000000     100.000000     100.000000     100.000000
